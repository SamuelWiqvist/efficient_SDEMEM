# %%
using PyPlot
using Statistics
using CSV
using StatsBase

# %%
cd("..") # set correct working directory 
cd("..") 
pwd() # the path should go to the folder with the .git file
# Out:
# "/home/samuel/Documents/projects/cpmmh for sdemems/code"

# %%
res_99_100 = Matrix(CSV.read("data/SDEMEM OU/cpmmh for plot mess vs N/run_time_ess_mess_0.99_100.csv",allowmissing=:auto));
res_999_50 = Matrix(CSV.read("data/SDEMEM OU/cpmmh for plot mess vs N/run_time_ess_mess_0.999_50.csv",allowmissing=:auto));
# Out:
# ┌ Warning: `allowmissing` is a deprecated keyword argument
# └ @ CSV /home/samuel/.julia/packages/CSV/76SRf/src/CSV.jl:330
# ┌ Warning: `allowmissing` is a deprecated keyword argument
# └ @ CSV /home/samuel/.julia/packages/CSV/76SRf/src/CSV.jl:330

# %%
res_99_100
# Out:
# 25×5 Array{Float64,2}:
#   1.0  209.653   912.251  4.35123  0.0
#   2.0  209.921   711.581  3.38976  0.0
#   3.0  210.357   899.81   4.27754  0.0
#   4.0  209.765   475.279  2.26577  0.0
#   5.0  211.03    746.995  3.53976  0.0
#   6.0  211.654   900.247  4.25338  0.0
#   7.0  209.717   748.94   3.5712   0.0
#   8.0  210.066   981.013  4.67002  0.0
#   9.0  210.096   775.54   3.69136  0.0
#  10.0  209.464   497.422  2.37474  0.0
#  11.0  210.257  1011.17   4.80919  0.0
#  12.0  205.408   585.036  2.84817  0.0
#  13.0  210.607   644.285  3.05918  0.0
#  14.0  206.026   784.199  3.80632  0.0
#  15.0  206.885   850.802  4.11244  0.0
#  16.0  206.656   732.207  3.54312  0.0
#  17.0  206.172   682.281  3.30927  0.0
#  18.0  208.096   762.526  3.66429  0.0
#  19.0  208.781  1086.87   5.2058   0.0
#  20.0  211.385   926.221  4.38168  0.0
#  21.0  210.328   910.462  4.32877  0.0
#  22.0  211.153   783.344  3.70984  0.0
#  23.0  208.733   703.249  3.36913  0.0
# ...

# %%
res_999_50
# Out:
# 25×5 Array{Float64,2}:
#   1.0  117.811  690.945  5.86486  0.0
#   2.0  118.621  449.791  3.79182  0.0
#   3.0  118.49   526.264  4.44144  0.0
#   4.0  119.648  734.398  6.13798  0.0
#   5.0  119.507  702.233  5.87607  0.0
#   6.0  118.091  449.015  3.80228  0.0
#   7.0  118.594  643.777  5.42839  0.0
#   8.0  118.269  488.118  4.12719  0.0
#   9.0  118.671  585.293  4.93206  0.0
#  10.0  118.375  590.14   4.98534  0.0
#  11.0  119.132  733.427  6.15642  0.0
#  12.0  119.15   627.898  5.26982  0.0
#  13.0  118.321  409.807  3.46352  0.0
#  14.0  110.753  593.774  5.36126  0.0
#  15.0  110.219  517.22   4.69267  0.0
#  16.0  110.164  549.786  4.99063  0.0
#  17.0  110.409  615.173  5.57178  0.0
#  18.0  110.643  643.338  5.81453  0.0
#  19.0  109.766  481.032  4.38233  0.0
#  20.0  119.087  650.904  5.4658   0.0
#  21.0  109.05   632.816  5.80297  0.0
#  22.0  109.418  778.012  7.11047  0.0
#  23.0  109.597  535.124  4.88264  0.0
#  24.0  109.772  683.044  6.22241  0.0
# ...

# %%
println(mean(res_99_100[:,3]))
println(std(res_99_100[:,3]))
println(percentile(res_99_100[:,3], [25,75]))
println(std(res_99_100[:,3])/sqrt(25))

PyPlot.figure()
PyPlot.boxplot(res_99_100[:,3])
# Out:
# 791.1930813411108
# 150.65296114970852
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# [711.581, 905.888]
# 30.130592229941705
# Dict{Any,Any} with 6 entries:
#   "means"    => Any[]
#   "whiskers" => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "fliers"   => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "boxes"    => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "caps"     => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "medians"  => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…

# %%
println(mean(res_999_50[:,3]))
println(mean(res_999_50[:,3]))
println(std(res_999_50[:,3]))
println(std(res_999_50[:,3])/sqrt(25))
println(percentile(res_999_50[:,3], [25,75]))


PyPlot.figure()
PyPlot.boxplot(res_999_50[:,3])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 599.5241607857959
# 599.5241607857959
# 98.97570331110451
# 19.795140662220902
# [526.264, 676.776]
# Dict{Any,Any} with 6 entries:
#   "means"    => Any[]
#   "whiskers" => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "fliers"   => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "boxes"    => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "caps"     => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "medians"  => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…

# %%
println(mean(res_99_100[:,2]))
println(std(res_99_100[:,2]))
println(percentile(res_99_100[:,2], [25,75]))
println(std(res_99_100[:,2])/sqrt(25))

PyPlot.figure()
PyPlot.boxplot(res_99_100[:,2])
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 173.10091942535067
# 1.761876699898378
# [171.942, 174.77]
# 0.3523753399796756
# Dict{Any,Any} with 6 entries:
#   "means"    => Any[]
#   "whiskers" => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "fliers"   => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "boxes"    => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "caps"     => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…
#   "medians"  => PyCall.PyObject[PyObject <matplotlib.lines.Line2D object at 0x7…

# %%
res_99_100
# Out:
# 25×5 Array{Float64,2}:
#   1.0  170.349  585.8    3.43882  0.0
#   2.0  172.005  694.726  4.03898  0.0
#   3.0  171.861  506.462  2.94693  0.0
#   4.0  171.335  768.665  4.48632  0.0
#   5.0  171.975  455.929  2.65113  0.0
#   6.0  172.005  595.853  3.46416  0.0
#   7.0  172.568  554.015  3.21041  0.0
#   8.0  172.416  493.484  2.86217  0.0
#   9.0  175.278  621.74   3.54717  0.0
#  10.0  174.628  385.839  2.20949  0.0
#  11.0  173.91   830.629  4.7762   0.0
#  12.0  175.952  656.873  3.73325  0.0
#  13.0  173.688  503.119  2.89668  0.0
#  14.0  175.025  653.325  3.73276  0.0
#  15.0  175.273  645.371  3.68209  0.0
#  16.0  174.63   620.149  3.55122  0.0
#  17.0  174.77   527.388  3.01762  0.0
#  18.0  174.865  617.587  3.5318   0.0
#  19.0  175.92   882.114  5.0143   0.0
#  20.0  171.942  650.071  3.78076  0.0
#  21.0  170.748  742.871  4.35067  0.0
#  22.0  172.147  600.871  3.49046  0.0
#  23.0  171.272  631.677  3.68814  0.0
#  24.0  172.061  629.834  3.66053  0.0
# ...
